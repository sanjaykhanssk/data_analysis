# %% [raw]
# A few questions that can be answered using this dataset are:
# 1. What did India export the most in any given year?
# 2. Which commodity forms a major chunk of trade? Does it conform to theories of international trade?
# 3. How has the trade between India and any given country grown over time?
#
# A visualization of this dataset would be a great way to explore more such questions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("india_trade/2018-2010_import.csv")

# %%
df.head()
# Out:
#    HSCode                                          Commodity   value  \
# 0       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...    0.00
# 1       7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   12.38
# 2       8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  268.60
# 3       9                      COFFEE, TEA, MATE AND SPICES.   35.48
# 4      11  PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...     NaN
#
#            country  year
# 0  AFGHANISTAN TIS  2018
# 1  AFGHANISTAN TIS  2018
# 2  AFGHANISTAN TIS  2018
# 3  AFGHANISTAN TIS  2018
# 4  AFGHANISTAN TIS  2018

# %%
df.shape
# Out:
# (93095, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93095 entries, 0 to 93094
# Data columns (total 5 columns):
# HSCode       93095 non-null int64
# Commodity    93095 non-null object
# value        79068 non-null float64
# country      93095 non-null object
# year         93095 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.6+ MB

# %%
df.isna().sum()
# Out:
# HSCode           0
# Commodity        0
# value        14027
# country          0
# year             0
# dtype: int64

# %%
df.isna()
# Out:
#        HSCode  Commodity  value  country   year
# 0       False      False  False    False  False
# 1       False      False  False    False  False
# 2       False      False  False    False  False
# 3       False      False  False    False  False
# 4       False      False   True    False  False
# 5       False      False  False    False  False
# 6       False      False  False    False  False
# 7       False      False  False    False  False
# 8       False      False  False    False  False
# 9       False      False  False    False  False
# 10      False      False   True    False  False
# 11      False      False  False    False  False
# 12      False      False   True    False  False
# 13      False      False  False    False  False
# 14      False      False  False    False  False
# 15      False      False  False    False  False
# 16      False      False  False    False  False
# 17      False      False  False    False  False
# 18      False      False  False    False  False
# 19      False      False  False    False  False
# 20      False      False  False    False  False
# 21      False      False   True    False  False
# 22      False      False  False    False  False
# 23      False      False  False    False  False
# 24      False      False  False    False  False
# 25      False      False  False    False  False
# 26      False      False   True    False  False
# 27      False      False   True    False  False
# 28      False      False   True    False  False
# 29      False      False  False    False  False
# ...       ...        ...    ...      ...    ...
# 93065   False      False  False    False  False
# 93066   False      False   True    False  False
# 93067   False      False  False    False  False
# 93068   False      False  False    False  False
# 93069   False      False  False    False  False
# 93070   False      False  False    False  False
# 93071   False      False  False    False  False
# 93072   False      False  False    False  False
# 93073   False      False  False    False  False
# 93074   False      False   True    False  False
# 93075   False      False   True    False  False
# 93076   False      False   True    False  False
# 93077   False      False  False    False  False
# 93078   False      False   True    False  False
# 93079   False      False  False    False  False
# 93080   False      False  False    False  False
# 93081   False      False  False    False  False
# 93082   False      False  False    False  False
# 93083   False      False  False    False  False
# 93084   False      False  False    False  False
# 93085   False      False  False    False  False
# 93086   False      False   True    False  False
# 93087   False      False  False    False  False
# 93088   False      False   True    False  False
# 93089   False      False  False    False  False
# 93090   False      False  False    False  False
# 93091   False      False  False    False  False
# 93092   False      False   True    False  False
# 93093   False      False   True    False  False
# 93094   False      False   True    False  False
#
# [93095 rows x 5 columns]

# %%
sns.heatmap(df.isna())

# %% [raw]
# The Value column is Price in " $ "
# , so we need to drop it if it's NAN , because if NAN means 0 , that means  there's no import on that thing right , I think so  ,
# let's do this without mercy let's drop it

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (79068, 5)

# %%
sns.heatmap(df.isna())

# %%
df.isna().sum()
# Out:
# HSCode       0
# Commodity    0
# value        0
# country      0
# year         0
# dtype: int64

# %% [raw]
# Now All the columns are semes to be good

# %% [markdown]
# # So now lets move to some visulization part with this data set

# %%
df.groupby("year").plot(title="year")
# Out:
# year
# 2010    AxesSubplot(0.125,0.125;0.775x0.755)
# 2011    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012    AxesSubplot(0.125,0.125;0.775x0.755)
# 2013    AxesSubplot(0.125,0.125;0.775x0.755)
# 2014    AxesSubplot(0.125,0.125;0.775x0.755)
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017    AxesSubplot(0.125,0.125;0.775x0.755)
# 2018    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df_group = df.groupby("year")

# %% [markdown]
# # Getting the importing amount details over the years

# %%
imp_years = df_group.sum()["value"]

# %%
plt.figure(figsize=(10,10))
plt.title("Import from other countries 2010 - 2018")
plt.ylabel("Year 2010-2018")
plt.xlabel("Amount in US $")
sns.barplot(x=imp_years.values , y=imp_years.index , alpha=0.4 ,orient="h" )
plt.show()

# %% [markdown]
# # The Country where we're(India) importing Maximum in each years

# %%
df_country = df.pivot_table(index="year"  ,columns="country"  , values="value" , aggfunc="sum")

# %%
df_country = df_country.unstack().reset_index()

# %%
df_country.head()
# Out:
#            country  year       0
# 0  AFGHANISTAN TIS  2010  146.01
# 1  AFGHANISTAN TIS  2011  132.49
# 2  AFGHANISTAN TIS  2012  159.53
# 3  AFGHANISTAN TIS  2013  208.76
# 4  AFGHANISTAN TIS  2014  261.92

# %%
df_country.rename(columns={0:"Values"} , inplace=True)

# %%
df_country.sort_values(by=["year" , "Values"] , ascending=False , inplace=True)

# %%
df_country.drop_duplicates(subset="year" , inplace=True)

# %%
df_country["year_country"] = df_country["year"].astype("str")+"__" +df_country["country"]

# %%
df_country
# Out:
#         country  year     Values      year_country
# 386  CHINA P RP  2018  140638.58  2018__CHINA P RP
# 385  CHINA P RP  2017  152760.70  2017__CHINA P RP
# 384  CHINA P RP  2016   61282.66  2016__CHINA P RP
# 383  CHINA P RP  2015   61707.54  2015__CHINA P RP
# 382  CHINA P RP  2014   60412.84  2014__CHINA P RP
# 381  CHINA P RP  2013   51034.30  2013__CHINA P RP
# 380  CHINA P RP  2012   52247.97  2012__CHINA P RP
# 379  CHINA P RP  2011   55313.17  2011__CHINA P RP
# 378  CHINA P RP  2010   43479.39  2010__CHINA P RP

# %%
df_country.drop(["year" , "country"] , axis=1 , inplace=True)

# %%
plt.figure(figsize=(8,8))
plt.title("India's most Importing Country in each year")
sns.barplot(x="year_country" , y="Values" , data=df_country)
plt.ylabel("Amount in USD $")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# A few questions that can be answered using this dataset are:
# 1. What did India export the most in any given year?
# 2. Which commodity forms a major chunk of trade? Does it conform to theories of international trade?
# 3. How has the trade between India and any given country grown over time?

# %% [markdown]
# #  1 , 2 . What did India export the most in any given year? Which commodity forms a major chunk of trade?

# %%
df_hs_count = df.HSCode.value_counts()[:10]

# %%
df_hs_code = df[["HSCode" , "Commodity"]].drop_duplicates(subset="HSCode").sort_values(by="HSCode")

# %%
df_hs_count = df_hs_count.to_frame()

# %%
df_hs_count
# Out:
#     HSCode
# 85    1933
# 84    1843
# 72    1685
# 39    1597
# 76    1592
# 90    1481
# 74    1363
# 73    1345
# 44    1298
# 41    1271

# %%
df_hs_code.head()
# Out:
#      HSCode                                          Commodity
# 131       1                                      LIVE ANIMALS.
# 215       2                        MEAT AND EDIBLE MEAT OFFAL.
# 132       3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...
# 133       4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...
# 0         5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...

# %%
df_hs_count.rename(columns={"HSCode":"Count"} , inplace=True)

# %%
df_hs_count.reset_index(inplace=True)

# %%
df_hs_count.rename(columns={"index":"HSCode"} , inplace=True)

# %%
df_hs_code
# Out:
#       HSCode                                          Commodity
# 131        1                                      LIVE ANIMALS.
# 215        2                        MEAT AND EDIBLE MEAT OFFAL.
# 132        3  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...
# 133        4  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...
# 0          5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...
# 134        6  LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...
# 1          7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.
# 2          8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...
# 3          9                      COFFEE, TEA, MATE AND SPICES.
# 138       10                                           CEREALS.
# 139       11  PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...
# 5         12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...
# 6         13  LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...
# 1401      14  VEGETABLE PLAITING MATERIALS; VEGETABLE PRODUC...
# 142       15  ANIMAL OR VEGETABLE FATS AND OILS AND THEIR CL...
# 314       16  PREPARATIONS OF MEAT, OF FISH OR OF CRUSTACEAN...
# 227       17                    SUGARS AND SUGAR CONFECTIONERY.
# 30        18                      COCOA AND COCOA PREPARATIONS.
# 229       19  PREPARATIONS OF CEREALS, FLOUR, STARCH OR MILK...
# 7         20  PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTH...
# 231       21                 MISCELLANEOUS EDIBLE PREPARATIONS.
# 145       22                    BEVERAGES, SPIRITS AND VINEGAR.
# 146       23  RESIDUES AND WASTE FROM THE FOOD INDUSTRIES; P...
# 209       24      TOBACCO AND MANUFACTURED TOBACCO SUBSTITUTES.
# 8         25  SALT; SULPHUR; EARTHS AND STONE; PLASTERING MA...
# 32        26                                ORES, SLAG AND ASH.
# 9         27  MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...
# 151       28  INORGANIC CHEMICALS; ORGANIC OR INORGANIC COMP...
# 57        29                                  ORGANIC CHEMICALS
# 153       30                            PHARMACEUTICAL PRODUCTS
# ...      ...                                                ...
# 275       69                                  CERAMIC PRODUCTS.
# 39        70                               GLASS AND GLASSWARE.
# 17        71  NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...
# 18        72                                     IRON AND STEEL
# 41        73                          ARTICLES OF IRON OR STEEL
# 19        74                       COPPER AND ARTICLES THEREOF.
# 281       75                       NICKEL AND ARTICLES THEREOF.
# 86        76                    ALUMINIUM AND ARTICLES THEREOF.
# 72        78                         LEAD AND ARTICLES THEREOF.
# 109       79                         ZINC AND ARTICLES THEREOF.
# 374       80                          TIN AND ARTICLES THEREOF.
# 20        81      OTHER BASE METALS; CERMETS; ARTICLES THEREOF.
# 110       82  TOOLS IMPLEMENTS, CUTLERY, SPOONS AND FORKS, O...
# 43        83              MISCELLANEOUS ARTICLES OF BASE METAL.
# 22        84  NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...
# 23        85  ELECTRICAL MACHINERY AND EQUIPMENT AND PARTS T...
# 76        86  RAILWAY OR TRAMWAY LOCOMOTIVES, ROLLING-STOCK ...
# 46        87  VEHICLES OTHER THAN RAILWAY OR TRAMWAY ROLLING...
# 292       88           AIRCRAFT, SPACECRAFT, AND PARTS THEREOF.
# 293       89              SHIPS, BOATS AND FLOATING STRUCTURES.
# 24        90  OPTICAL, PHOTOGRAPHIC CINEMATOGRAPHIC MEASURIN...
# 295       91              CLOCKS AND WATCHES AND PARTS THEREOF.
# 296       92  MUSICAL INSTRUMENTS; PARTS AND ACCESSORIES OF ...
# 297       93  ARMS AND AMMUNITION; PARTS AND ACCESSORIES THE...
# 48        94  FURNITURE; BEDDING, MATTRESSES, MATTRESS SUPPO...
# 188       95  TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...
# 25        96               MISCELLANEOUS MANUFACTURED ARTICLES.
# 301       97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.
# 79        98                  PROJECT GOODS; SOME SPECIAL USES.
# 80        99                               MISCELLANEOUS GOODS.
#
# [98 rows x 2 columns]

# %%
df_hs_count
# Out:
#    HSCode  Count
# 0      85   1933
# 1      84   1843
# 2      72   1685
# 3      39   1597
# 4      76   1592
# 5      90   1481
# 6      74   1363
# 7      73   1345
# 8      44   1298
# 9      41   1271

# %%
df_hs_count = df_hs_code.join(df_hs_count , on="HSCode" , rsuffix="other" ).dropna()

# %%
del df_hs_code

# %%
df_hs_count.drop(columns="HSCode" , inplace=True)

# %%
df_hs_count.rename(columns={"HSCodeother":"HSCode"} , inplace=True)

# %%
df_hs_count
# Out:
#                                              Commodity  HSCode   Count
# 131                                      LIVE ANIMALS.    84.0  1843.0
# 215                        MEAT AND EDIBLE MEAT OFFAL.    72.0  1685.0
# 132  FISH AND CRUSTACEANS, MOLLUSCS AND OTHER AQUAT...    39.0  1597.0
# 133  DAIRY PRODUCE; BIRDS' EGGS; NATURAL HONEY; EDI...    76.0  1592.0
# 0    PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...    90.0  1481.0
# 134  LIVE TREES AND OTHER PLANTS; BULBS; ROOTS AND ...    74.0  1363.0
# 1      EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.    73.0  1345.0
# 2    EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...    44.0  1298.0
# 3                        COFFEE, TEA, MATE AND SPICES.    41.0  1271.0

# %%
plt.title("Top Importing Products In India 2010 - 2018")
sns.barplot(data=df_hs_count , x="Count" , y="Commodity")

# %% [markdown]
# # 3 . Trade grown India between any given country

# %%
df.country.unique()
# Out:
# array(['AFGHANISTAN TIS', 'ALBANIA', 'ALGERIA', 'AMERI SAMOA', 'ANDORRA',
#        'ANGOLA', 'ANGUILLA', 'ANTARTICA', 'ANTIGUA', 'ARGENTINA',
#        'ARMENIA', 'ARUBA', 'AUSTRALIA', 'AUSTRIA', 'AZERBAIJAN',
#        'BAHAMAS', 'BAHARAIN IS', 'BANGLADESH PR', 'BARBADOS', 'BELARUS',
#        'BELGIUM', 'BELIZE', 'BENIN', 'BERMUDA', 'BHUTAN', 'BOLIVIA',
#        'BOSNIA-HRZGOVIN', 'BOTSWANA', 'BR VIRGN IS', 'BRAZIL', 'BRUNEI',
#        'BULGARIA', 'BURKINA FASO', 'BURUNDI', 'C AFRI REP', 'CAMBODIA',
#        'CAMEROON', 'CANADA', 'CAPE VERDE IS', 'CAYMAN IS', 'CHAD',
#        'CHILE', 'CHINA P RP', 'COCOS IS', 'COLOMBIA', 'COMOROS',
#        'CONGO D. REP.', 'CONGO P REP', 'COOK IS', 'COSTA RICA',
#        "COTE D' IVOIRE", 'CROATIA', 'CUBA', 'CYPRUS', 'CZECH REPUBLIC',
#        'DENMARK', 'DJIBOUTI', 'DOMINIC REP', 'DOMINICA', 'ECUADOR',
#        'EGYPT A RP', 'EL SALVADOR', 'EQUTL GUINEA', 'ERITREA', 'ESTONIA',
#        'ETHIOPIA', 'FAROE IS.', 'FIJI IS', 'FINLAND', 'FR GUIANA',
#        'FR POLYNESIA', 'FRANCE', 'GABON', 'GAMBIA', 'GEORGIA', 'GERMANY',
#        'GHANA', 'GIBRALTAR', 'GREECE', 'GRENADA', 'GUADELOUPE', 'GUAM',
#        'GUATEMALA', 'GUINEA', 'GUINEA BISSAU', 'GUYANA', 'HAITI',
#        'HONDURAS', 'HONG KONG', 'HUNGARY', 'ICELAND', 'INDONESIA', 'IRAN',
#        'IRAQ', 'IRELAND', 'ISRAEL', 'ITALY', 'JAMAICA', 'JAPAN',
#        'JERSEY         ', 'JORDAN', 'KAZAKHSTAN', 'KENYA', 'KIRIBATI REP',
#        'KOREA DP RP', 'KOREA RP', 'KUWAIT', 'KYRGHYZSTAN', 'LAO PD RP',
#        'LATVIA', 'LEBANON', 'LESOTHO', 'LIBERIA', 'LIBYA',
#        'LIECHTENSTEIN', 'LITHUANIA', 'LUXEMBOURG', 'MACAO', 'MACEDONIA',
#        'MADAGASCAR', 'MALAWI', 'MALAYSIA', 'MALDIVES', 'MALI', 'MALTA',
#        'MARSHALL ISLAND', 'MARTINIQUE', 'MAURITANIA', 'MAURITIUS',
#        'MAYOTTE', 'MEXICO', 'MOLDOVA', 'MONACO', 'MONGOLIA', 'MONTENEGRO',
#        'MONTSERRAT', 'MOROCCO', 'MOZAMBIQUE', 'MYANMAR', 'N. MARIANA IS.',
#        'NAMIBIA', 'NAURU RP', 'NEPAL', 'NETHERLAND', 'NETHERLANDANTIL',
#        'NEW CALEDONIA', 'NEW ZEALAND', 'NICARAGUA', 'NIGER', 'NIGERIA',
#        'NORFOLK IS', 'NORWAY', 'OMAN', 'PAKISTAN IR', 'PALAU',
#        'PANAMA REPUBLIC', 'PAPUA N GNA', 'PARAGUAY', 'PERU',
#        'PHILIPPINES', 'PITCAIRN IS.', 'POLAND', 'PORTUGAL', 'PUERTO RICO',
#        'QATAR', 'REUNION', 'ROMANIA', 'RUSSIA', 'RWANDA', 'SAMOA',
#        'SAN MARINO', 'SAO TOME', 'SAUDI ARAB', 'SENEGAL', 'SERBIA',
#        'SEYCHELLES', 'SIERRA LEONE', 'SINGAPORE', 'SLOVAK REP',
#        'SLOVENIA', 'SOLOMON IS', 'SOMALIA', 'SOUTH AFRICA',
#        'SOUTH SUDAN ', 'SPAIN', 'SRI LANKA DSR', 'ST HELENA',
#        'ST KITT N A', 'ST LUCIA', 'ST VINCENT', 'STATE OF PALEST',
#        'SUDAN', 'SURINAME', 'SWAZILAND', 'SWEDEN', 'SWITZERLAND', 'SYRIA',
#        'TAIWAN', 'TAJIKISTAN', 'TANZANIA REP', 'THAILAND', 'TOGO',
#        'TOKELAU IS', 'TONGA', 'TRINIDAD', 'TUNISIA', 'TURKEY',
#        'TURKMENISTAN', 'TUVALU', 'U ARAB EMTS', 'U K', 'U S A', 'UGANDA',
#        'UKRAINE', 'UNSPECIFIED', 'URUGUAY',
#        'US MINOR OUTLYING ISLANDS               ', 'UZBEKISTAN',
#        'VATICAN CITY', 'VENEZUELA', 'VIETNAM SOC REP', 'VIRGIN IS US',
#        'YEMEN REPUBLC', 'ZAMBIA', 'ZIMBABWE', 'CHRISTMAS IS.',
#        'GREENLAND', 'GUERNSEY', 'NIUE IS', 'TIMOR LESTE', 'TURKS C IS',
#        'VANUATU REP', 'WALLIS F IS', 'HEARD MACDONALD', 'PANAMA C Z',
#        'FALKLAND IS', 'FR S ANT TR', 'ST PIERRE',
#        'UNION OF SERBIA & MONTENEGRO', 'MICRONESIA', 'PACIFIC IS'],
#       dtype=object)

# %%
df.head()
# Out:
#    HSCode                                          Commodity   value  \
# 0       5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...    0.00
# 1       7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   12.38
# 2       8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  268.60
# 3       9                      COFFEE, TEA, MATE AND SPICES.   35.48
# 5      12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...    8.32
#
#            country  year
# 0  AFGHANISTAN TIS  2018
# 1  AFGHANISTAN TIS  2018
# 2  AFGHANISTAN TIS  2018
# 3  AFGHANISTAN TIS  2018
# 5  AFGHANISTAN TIS  2018

# %%
given_country = "CROATIA"

# %%
country_df = df.groupby(["country" , "year"]).sum()["value"]

# %%
country_df = country_df.to_frame()

# %%
country_df.head()
# Out:
#      year  value
# 452  2010  28.06
# 453  2011  24.03
# 454  2012  18.07
# 455  2013   9.73
# 456  2014  28.63

# %%
country_df.reset_index(inplace=True)

# %%
country_df = country_df.loc[country_df["country"] == given_country][["year" , "value"]]

# %%
plt.figure()
plt.title(f"Trade Between India and {given_country} ")
plt.scatter(x=country_df.year , y=country_df.value)
sns.lineplot(x="year" , y="value" , data=country_df,)

# %%
df["value_year"] = df["value"].groupby(df["year"]).transform("sum")

# %%
df
# Out:
#        HSCode                                          Commodity   value  \
# 0           5  PRODUCTS OF ANIMAL ORIGIN, NOT ELSEWHERE SPECI...    0.00
# 1           7    EDIBLE VEGETABLES AND CERTAIN ROOTS AND TUBERS.   12.38
# 2           8  EDIBLE FRUIT AND NUTS; PEEL OR CITRUS FRUIT OR...  268.60
# 3           9                      COFFEE, TEA, MATE AND SPICES.   35.48
# 4          11  PRODUCTS OF THE MILLING INDUSTRY; MALT; STARCH...     NaN
# 5          12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...    8.32
# 6          13  LAC; GUMS, RESINS AND OTHER VEGETABLE SAPS AND...  108.78
# 7          20  PREPARATIONS OF VEGETABLES, FRUIT, NUTS OR OTH...    0.65
# 8          25  SALT; SULPHUR; EARTHS AND STONE; PLASTERING MA...    0.05
# 9          27  MINERAL FUELS, MINERAL OILS AND PRODUCTS OF TH...    0.00
# 10         39                      PLASTIC AND ARTICLES THEREOF.     NaN
# 11         41  RAW HIDES AND SKINS (OTHER THAN FURSKINS) AND ...    0.00
# 12         49  PRINTED BOOKDS, NEWSPAPERS, PICTURES AND OTHER...     NaN
# 13         51  WOOL, FINE OR COARSE ANIMAL HAIR, HORSEHAIR YA...    0.17
# 14         52                                            COTTON.    0.01
# 15         57         CARPETS AND OTHER TEXTILE FLOOR COVERINGS.    0.02
# 16         68  ARTICLES OF STONE, PLASTER, CEMENT, ASBESTOS, ...    0.01
# 17         71  NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...    0.01
# 18         72                                     IRON AND STEEL    0.02
# 19         74                       COPPER AND ARTICLES THEREOF.    0.36
# 20         81      OTHER BASE METALS; CERMETS; ARTICLES THEREOF.    0.00
# 21         82  TOOLS IMPLEMENTS, CUTLERY, SPOONS AND FORKS, O...     NaN
# 22         84  NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...    0.00
# 23         85  ELECTRICAL MACHINERY AND EQUIPMENT AND PARTS T...    0.56
# 24         90  OPTICAL, PHOTOGRAPHIC CINEMATOGRAPHIC MEASURIN...    0.02
# 25         96               MISCELLANEOUS MANUFACTURED ARTICLES.    0.00
# 26         97      WORKS OF ART COLLECTORS' PIECES AND ANTIQUES.     NaN
# 27         98                  PROJECT GOODS; SOME SPECIAL USES.     NaN
# 28         99                               MISCELLANEOUS GOODS.     NaN
# 29         12  OIL SEEDS AND OLEA. FRUITS; MISC. GRAINS, SEED...    0.54
# ...       ...                                                ...     ...
# 93065      41  RAW HIDES AND SKINS (OTHER THAN FURSKINS) AND ...    0.50
# 93066      52                                            COTTON.     NaN
# 93067      71  NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...   16.75
# 93068      72                                     IRON AND STEEL    0.28
# 93069      74                       COPPER AND ARTICLES THEREOF.    6.23
# 93070      76                    ALUMINIUM AND ARTICLES THEREOF.    0.00
# 93071      78                         LEAD AND ARTICLES THEREOF.    0.11
# 93072      81      OTHER BASE METALS; CERMETS; ARTICLES THEREOF.    3.57
# 93073      84  NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...    0.02
# 93074      85  ELECTRICAL MACHINERY AND EQUIPMENT AND PARTS T...     NaN
# 93075      87  VEHICLES OTHER THAN RAILWAY OR TRAMWAY ROLLING...     NaN
# 93076      94  FURNITURE; BEDDING, MATTRESSES, MATTRESS SUPPO...     NaN
# 93077      95  TOYS, GAMES AND SPORTS REQUISITES; PARTS AND A...    0.00
# 93078      98                  PROJECT GOODS; SOME SPECIAL USES.     NaN
# 93079      99                               MISCELLANEOUS GOODS.    0.43
# 93080      24      TOBACCO AND MANUFACTURED TOBACCO SUBSTITUTES.    5.22
# 93081      25  SALT; SULPHUR; EARTHS AND STONE; PLASTERING MA...    0.11
# 93082      29                                  ORGANIC CHEMICALS    0.00
# 93083      32  TANNING OR DYEING EXTRACTS; TANNINS AND THEIR ...    2.95
# 93084      40                       RUBBER AND ARTICLES THEREOF.    0.04
# 93085      41  RAW HIDES AND SKINS (OTHER THAN FURSKINS) AND ...    0.73
# 93086      52                                            COTTON.     NaN
# 93087      68  ARTICLES OF STONE, PLASTER, CEMENT, ASBESTOS, ...    0.09
# 93088      71  NATURAL OR CULTURED PEARLS,PRECIOUS OR SEMIPRE...     NaN
# 93089      75                       NICKEL AND ARTICLES THEREOF.    2.34
# 93090      81      OTHER BASE METALS; CERMETS; ARTICLES THEREOF.    0.14
# 93091      82  TOOLS IMPLEMENTS, CUTLERY, SPOONS AND FORKS, O...    0.00
# 93092      84  NUCLEAR REACTORS, BOILERS, MACHINERY AND MECHA...     NaN
# 93093      85  ELECTRICAL MACHINERY AND EQUIPMENT AND PARTS T...     NaN
# 93094      99                               MISCELLANEOUS GOODS.     NaN
#
#                country  year  value_year
# 0      AFGHANISTAN TIS  2018  1028142.66
# 1      AFGHANISTAN TIS  2018  1028142.66
# 2      AFGHANISTAN TIS  2018  1028142.66
# 3      AFGHANISTAN TIS  2018  1028142.66
# 4      AFGHANISTAN TIS  2018  1028142.66
# 5      AFGHANISTAN TIS  2018  1028142.66
# 6      AFGHANISTAN TIS  2018  1028142.66
# 7      AFGHANISTAN TIS  2018  1028142.66
# 8      AFGHANISTAN TIS  2018  1028142.66
# 9      AFGHANISTAN TIS  2018  1028142.66
# 10     AFGHANISTAN TIS  2018  1028142.66
# 11     AFGHANISTAN TIS  2018  1028142.66
# 12     AFGHANISTAN TIS  2018  1028142.66
# 13     AFGHANISTAN TIS  2018  1028142.66
# 14     AFGHANISTAN TIS  2018  1028142.66
# 15     AFGHANISTAN TIS  2018  1028142.66
# 16     AFGHANISTAN TIS  2018  1028142.66
# 17     AFGHANISTAN TIS  2018  1028142.66
# 18     AFGHANISTAN TIS  2018  1028142.66
# 19     AFGHANISTAN TIS  2018  1028142.66
# 20     AFGHANISTAN TIS  2018  1028142.66
# 21     AFGHANISTAN TIS  2018  1028142.66
# 22     AFGHANISTAN TIS  2018  1028142.66
# 23     AFGHANISTAN TIS  2018  1028142.66
# 24     AFGHANISTAN TIS  2018  1028142.66
# 25     AFGHANISTAN TIS  2018  1028142.66
# 26     AFGHANISTAN TIS  2018  1028142.66
# 27     AFGHANISTAN TIS  2018  1028142.66
# 28     AFGHANISTAN TIS  2018  1028142.66
# 29             ALBANIA  2018  1028142.66
# ...                ...   ...         ...
# 93065           ZAMBIA  2010   369762.25
# 93066           ZAMBIA  2010   369762.25
# 93067           ZAMBIA  2010   369762.25
# 93068           ZAMBIA  2010   369762.25
# 93069           ZAMBIA  2010   369762.25
# 93070           ZAMBIA  2010   369762.25
# 93071           ZAMBIA  2010   369762.25
# 93072           ZAMBIA  2010   369762.25
# 93073           ZAMBIA  2010   369762.25
# 93074           ZAMBIA  2010   369762.25
# 93075           ZAMBIA  2010   369762.25
# 93076           ZAMBIA  2010   369762.25
# 93077           ZAMBIA  2010   369762.25
# 93078           ZAMBIA  2010   369762.25
# 93079           ZAMBIA  2010   369762.25
# 93080         ZIMBABWE  2010   369762.25
# 93081         ZIMBABWE  2010   369762.25
# 93082         ZIMBABWE  2010   369762.25
# 93083         ZIMBABWE  2010   369762.25
# 93084         ZIMBABWE  2010   369762.25
# 93085         ZIMBABWE  2010   369762.25
# 93086         ZIMBABWE  2010   369762.25
# 93087         ZIMBABWE  2010   369762.25
# 93088         ZIMBABWE  2010   369762.25
# 93089         ZIMBABWE  2010   369762.25
# 93090         ZIMBABWE  2010   369762.25
# 93091         ZIMBABWE  2010   369762.25
# 93092         ZIMBABWE  2010   369762.25
# 93093         ZIMBABWE  2010   369762.25
# 93094         ZIMBABWE  2010   369762.25
#
# [93095 rows x 6 columns]
